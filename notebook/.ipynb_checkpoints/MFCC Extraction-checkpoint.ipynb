# %% [markdown]
# # Speech analysis and re-synthesis
#
# This notebook demonstrates how to analyze speech and re-synthesis speech waveform from speech parameters using [pysptk](https://github.com/r9y9/pysptk) (and other useful speech/audio/music analysis packages). Synthesized audio examples are provided so that you are able to compare synthesis filters on your browser.
#
# ## Requirements
#
# - pysptk: https://github.com/r9y9/pysptk
# - scipy
# - librosa: https://github.com/bmcfee/librosa
# - seaborn: https://github.com/mwaskom/seaborn

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib
import seaborn
seaborn.set(style="dark")
rcParams['figure.figsize'] = (16, 5)

# %%
from IPython.display import Audio
import IPython.display

# %%
import numpy as np
import sys
import librosa
import librosa.display
import pysptk
from scipy.io import wavfile

# %% [markdown]
# ## Data Load

# %%
import copy
import fnmatch
import os
import random
import re

import pandas as pd
import json

def find_files(directory, pattern='*.wav'):
    '''Recursively finds all files matching the pattern.'''
    files = []
    for root, dirnames, filenames in os.walk(directory):
        for filename in fnmatch.filter(filenames, pattern):
            files.append(os.path.join(root, filename))
    return files

# %% [markdown]
# ## Mel-frequency cepstrum extraction

# %%
def generate_mfcc(directory, sample_rate, lc_dir_name, n_mfcc, lc_ext_name=".csv", overwrite=False):
    files = find_files(directory,  pattern="*.wav")
    for index, filename in enumerate(files):
        print(str(index)+"/"+str(len(files)))
        print(filename)
        lc_filename = copy.deepcopy(filename)
        if lc_filename.endswith('.wav'):
            lc_filename = lc_filename[:-4] + lc_ext_name
        lc_filename = lc_filename.replace("wav", lc_dir_name)
        if os.path.isfile(lc_filename) and not overwrite:
            IPython.display.clear_output(wait=True)
            continue
        audio, _ = librosa.load(filename, sr=sample_rate, mono=True)
        mfcc = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc, n_fft=1024, hop_length=128) # shape = (n_mfcc, t)
        df = pd.DataFrame(mfcc.T)
        print(str(mfcc.T.shape))
        if not os.path.exists(os.path.dirname(lc_filename)):
            try:
                os.makedirs(os.path.dirname(lc_filename))
            except OSError as exc: # Guard against race condition
                if exc.errno != errno.EEXIST:
                    raise
        print(lc_filename)
        df.to_csv(lc_filename, sep=',', header=None, index=None) 
        IPython.display.clear_output(wait=True)

# %%
def generate_lc_map(directory, old_name, new_name, json_name):
    files = find_files(directory, pattern="*.wav")
    print("files length: {}".format(len(files)))
    lookup = {}
    for filename in files:
        p_filename = filename.split(directory)[-1]
        p_lc_filename = p_filename.replace(old_name, new_name).replace(".wav", ".csv")
        #p_lc_filename = "../../mfcc40/p225/"+p_filename.replace(".wav", ".csv")
        lookup[p_filename] = p_lc_filename
    with open(directory+"/"+json_name, "w") as output:
        print("Export to "+directory+"/"+json_name)
        json.dump(lookup, output)
    print(lookup)

# %%
generate_mfcc("../../cmu_us_slt_arctic", 16000, "mfcc20_16k", 20, lc_ext_name=".csv", overwrite=True)
# Out:
# 1131/1132
# ../../cmu_us_slt_arctic/wav/arctic_a0166.wav

# %%
generate_lc_map("../../cmu_us_slt_arctic",  "/wav/", "mfcc20_16k/", "mfcc40_48k.json")
# Out:
# files length: 1132
# Export to ../../cmu_us_slt_arctic/mfcc40_48k.json
# {'/wav/arctic_a0340.wav': 'mfcc40_48k/arctic_a0340.csv', '/wav/arctic_b0166.wav': 'mfcc40_48k/arctic_b0166.csv', '/wav/arctic_b0300.wav': 'mfcc40_48k/arctic_b0300.csv', '/wav/arctic_b0463.wav': 'mfcc40_48k/arctic_b0463.csv', '/wav/arctic_a0004.wav': 'mfcc40_48k/arctic_a0004.csv', '/wav/arctic_b0491.wav': 'mfcc40_48k/arctic_b0491.csv', '/wav/arctic_a0475.wav': 'mfcc40_48k/arctic_a0475.csv', '/wav/arctic_b0350.wav': 'mfcc40_48k/arctic_b0350.csv', '/wav/arctic_b0504.wav': 'mfcc40_48k/arctic_b0504.csv', '/wav/arctic_b0241.wav': 'mfcc40_48k/arctic_b0241.csv', '/wav/arctic_b0209.wav': 'mfcc40_48k/arctic_b0209.csv', '/wav/arctic_b0204.wav': 'mfcc40_48k/arctic_b0204.csv', '/wav/arctic_a0057.wav': 'mfcc40_48k/arctic_a0057.csv', '/wav/arctic_a0425.wav': 'mfcc40_48k/arctic_a0425.csv', '/wav/arctic_b0104.wav': 'mfcc40_48k/arctic_b0104.csv', '/wav/arctic_a0109.wav': 'mfcc40_48k/arctic_a0109.csv', '/wav/arctic_b0092.wav': 'mfcc40_48k/arctic_b0092.csv', '/wav/arctic_a0512.wav': 'mfcc40_48k/arctic_a0512.csv', '/wav/arctic_b0123.wav': 'mfcc40_48k/arctic_b0123.csv', '/wav/arctic_a0493.wav': 'mfcc40_48k/arctic_a0493.csv', '/wav/arctic_b0127.wav': 'mfcc40_48k/arctic_b0127.csv', '/wav/arctic_a0543.wav': 'mfcc40_48k/arctic_a0543.csv', '/wav/arctic_a0069.wav': 'mfcc40_48k/arctic_a0069.csv', '/wav/arctic_a0159.wav': 'mfcc40_48k/arctic_a0159.csv', '/wav/arctic_a0527.wav': 'mfcc40_48k/arctic_a0527.csv', '/wav/arctic_b0523.wav': 'mfcc40_48k/arctic_b0523.csv', '/wav/arctic_a0507.wav': 'mfcc40_48k/arctic_a0507.csv', '/wav/arctic_a0104.wav': 'mfcc40_48k/arctic_a0104.csv', '/wav/arctic_a0570.wav': 'mfcc40_48k/arctic_a0570.csv', '/wav/arctic_a0177.wav': 'mfcc40_48k/arctic_a0177.csv', '/wav/arctic_a0517.wav': 'mfcc40_48k/arctic_a0517.csv', '/wav/arctic_a0189.wav': 'mfcc40_48k/arctic_a0189.csv', '/wav/arctic_b0298.wav': 'mfcc40_48k/arctic_b0298.csv', '/wav/arctic_a0087.wav': 'mfcc40_48k/arctic_a0087.csv', '/wav/arctic_a0155.wav': 'mfcc40_48k/arctic_a0155.csv', '/wav/arctic_b0227.wav': 'mfcc40_48k/arctic_b0227.csv', '/wav/arctic_a0281.wav': 'mfcc40_48k/arctic_a0281.csv', '/wav/arctic_a0226.wav': 'mfcc40_48k/arctic_a0226.csv', '/wav/arctic_a0139.wav': 'mfcc40_48k/arctic_a0139.csv', '/wav/arctic_b0358.wav': 'mfcc40_48k/arctic_b0358.csv', '/wav/arctic_b0335.wav': 'mfcc40_48k/arctic_b0335.csv', '/wav/arctic_b0470.wav': 'mfcc40_48k/arctic_b0470.csv', '/wav/arctic_b0366.wav': 'mfcc40_48k/arctic_b0366.csv', '/wav/arctic_b0219.wav': 'mfcc40_48k/arctic_b0219.csv', '/wav/arctic_b0141.wav': 'mfcc40_48k/arctic_b0141.csv', '/wav/arctic_b0135.wav': 'mfcc40_48k/arctic_b0135.csv', '/wav/arctic_a0062.wav': 'mfcc40_48k/arctic_a0062.csv', '/wav/arctic_b0145.wav': 'mfcc40_48k/arctic_b0145.csv', '/wav/arctic_a0172.wav': 'mfcc40_48k/arctic_a0172.csv', '/wav/arctic_a0023.wav': 'mfcc40_48k/arctic_a0023.csv', '/wav/arctic_b0494.wav': 'mfcc40_48k/arctic_b0494.csv', '/wav/arctic_b0251.wav': 'mfcc40_48k/arctic_b0251.csv', '/wav/arctic_b0423.wav': 'mfcc40_48k/arctic_b0423.csv', '/wav/arctic_b0288.wav': 'mfcc40_48k/arctic_b0288.csv', '/wav/arctic_a0589.wav': 'mfcc40_48k/arctic_a0589.csv', '/wav/arctic_b0456.wav': 'mfcc40_48k/arctic_b0456.csv', '/wav/arctic_b0305.wav': 'mfcc40_48k/arctic_b0305.csv', '/wav/arctic_b0340.wav': 'mfcc40_48k/arctic_b0340.csv', '/wav/arctic_b0207.wav': 'mfcc40_48k/arctic_b0207.csv', '/wav/arctic_a0423.wav': 'mfcc40_48k/arctic_a0423.csv', '/wav/arctic_b0017.wav': 'mfcc40_48k/arctic_b0017.csv', '/wav/arctic_a0214.wav': 'mfcc40_48k/arctic_a0214.csv', '/wav/arctic_b0384.wav': 'mfcc40_48k/arctic_b0384.csv', '/wav/arctic_a0297.wav': 'mfcc40_48k/arctic_a0297.csv', '/wav/arctic_a0088.wav': 'mfcc40_48k/arctic_a0088.csv', '/wav/arctic_b0413.wav': 'mfcc40_48k/arctic_b0413.csv', '/wav/arctic_a0257.wav': 'mfcc40_48k/arctic_a0257.csv', '/wav/arctic_a0117.wav': 'mfcc40_48k/arctic_a0117.csv', '/wav/arctic_a0519.wav': 'mfcc40_48k/arctic_a0519.csv', '/wav/arctic_a0547.wav': 'mfcc40_48k/arctic_a0547.csv', '/wav/arctic_b0345.wav': 'mfcc40_48k/arctic_b0345.csv', '/wav/arctic_a0178.wav' ...

# %%
# generate_lc_map("../../VCTK-Corpus/wav48/p225")
# Out:
# files length: 231
# {'/p225_144.wav': '/p225_144.csv', '/p225_225.wav': '/p225_225.csv', '/p225_323.wav': '/p225_323.csv', '/p225_084.wav': '/p225_084.csv', '/p225_287.wav': '/p225_287.csv', '/p225_024.wav': '/p225_024.csv', '/p225_012.wav': '/p225_012.csv', '/p225_244.wav': '/p225_244.csv', '/p225_018.wav': '/p225_018.csv', '/p225_300.wav': '/p225_300.csv', '/p225_366.wav': '/p225_366.csv', '/p225_116.wav': '/p225_116.csv', '/p225_037.wav': '/p225_037.csv', '/p225_151.wav': '/p225_151.csv', '/p225_211.wav': '/p225_211.csv', '/p225_053.wav': '/p225_053.csv', '/p225_020.wav': '/p225_020.csv', '/p225_322.wav': '/p225_322.csv', '/p225_325.wav': '/p225_325.csv', '/p225_254.wav': '/p225_254.csv', '/p225_277.wav': '/p225_277.csv', '/p225_089.wav': '/p225_089.csv', '/p225_030.wav': '/p225_030.csv', '/p225_171.wav': '/p225_171.csv', '/p225_201.wav': '/p225_201.csv', '/p225_210.wav': '/p225_210.csv', '/p225_265.wav': '/p225_265.csv', '/p225_350.wav': '/p225_350.csv', '/p225_038.wav': '/p225_038.csv', '/p225_064.wav': '/p225_064.csv', '/p225_268.wav': '/p225_268.csv', '/p225_298.wav': '/p225_298.csv', '/p225_060.wav': '/p225_060.csv', '/p225_114.wav': '/p225_114.csv', '/p225_021.wav': '/p225_021.csv', '/p225_329.wav': '/p225_329.csv', '/p225_111.wav': '/p225_111.csv', '/p225_141.wav': '/p225_141.csv', '/p225_199.wav': '/p225_199.csv', '/p225_208.wav': '/p225_208.csv', '/p225_157.wav': '/p225_157.csv', '/p225_008.wav': '/p225_008.csv', '/p225_310.wav': '/p225_310.csv', '/p225_054.wav': '/p225_054.csv', '/p225_104.wav': '/p225_104.csv', '/p225_293.wav': '/p225_293.csv', '/p225_133.wav': '/p225_133.csv', '/p225_071.wav': '/p225_071.csv', '/p225_083.wav': '/p225_083.csv', '/p225_347.wav': '/p225_347.csv', '/p225_057.wav': '/p225_057.csv', '/p225_289.wav': '/p225_289.csv', '/p225_070.wav': '/p225_070.csv', '/p225_007.wav': '/p225_007.csv', '/p225_318.wav': '/p225_318.csv', '/p225_241.wav': '/p225_241.csv', '/p225_136.wav': '/p225_136.csv', '/p225_115.wav': '/p225_115.csv', '/p225_051.wav': '/p225_051.csv', '/p225_276.wav': '/p225_276.csv', '/p225_073.wav': '/p225_073.csv', '/p225_062.wav': '/p225_062.csv', '/p225_335.wav': '/p225_335.csv', '/p225_103.wav': '/p225_103.csv', '/p225_326.wav': '/p225_326.csv', '/p225_192.wav': '/p225_192.csv', '/p225_094.wav': '/p225_094.csv', '/p225_017.wav': '/p225_017.csv', '/p225_193.wav': '/p225_193.csv', '/p225_331.wav': '/p225_331.csv', '/p225_174.wav': '/p225_174.csv', '/p225_040.wav': '/p225_040.csv', '/p225_294.wav': '/p225_294.csv', '/p225_317.wav': '/p225_317.csv', '/p225_220.wav': '/p225_220.csv', '/p225_092.wav': '/p225_092.csv', '/p225_003.wav': '/p225_003.csv', '/p225_152.wav': '/p225_152.csv', '/p225_280.wav': '/p225_280.csv', '/p225_240.wav': '/p225_240.csv', '/p225_009.wav': '/p225_009.csv', '/p225_175.wav': '/p225_175.csv', '/p225_014.wav': '/p225_014.csv', '/p225_013.wav': '/p225_013.csv', '/p225_126.wav': '/p225_126.csv', '/p225_273.wav': '/p225_273.csv', '/p225_176.wav': '/p225_176.csv', '/p225_150.wav': '/p225_150.csv', '/p225_118.wav': '/p225_118.csv', '/p225_242.wav': '/p225_242.csv', '/p225_324.wav': '/p225_324.csv', '/p225_197.wav': '/p225_197.csv', '/p225_072.wav': '/p225_072.csv', '/p225_039.wav': '/p225_039.csv', '/p225_001.wav': '/p225_001.csv', '/p225_147.wav': '/p225_147.csv', '/p225_281.wav': '/p225_281.csv', '/p225_291.wav': '/p225_291.csv', '/p225_131.wav': '/p225_131.csv', '/p225_025.wav': '/p225_025.csv', '/p225_022.wav': '/p225_022.csv', '/p225_221.wav': '/p225_221.csv', '/p225_308.wav': '/p225_308.csv', '/p225_286.wav': '/p225_286.csv', '/p225_353.wav': '/p225_353.csv', '/p225_264.wav': '/p225_264.csv', '/p225_218.wav': '/p225_218.csv', '/p225_110.wav': '/p225_110.csv', '/p225_302.wav': '/p225_302.csv', '/p225_166.wav': '/p225_166.csv', '/p225_236.wav': '/p225_236.csv', '/p225_153.wav': '/p225_153.csv', '/p225_123.wav': '/p225_123.csv', '/p225_290.wav': '/p225_290.csv', '/p225_165.wav': '/p225_165.csv', '/p225_049.wav': '/p225_049.csv', '/p225_266.wav': '/p225_266.csv', '/p225_358.wav': '/p2 ...

# %%
# A = np.zeros((1000))
# mfcc = librosa.feature.mfcc(y=A, sr=16000) # shape = (n_mfcc, t)
# print(mfcc)
# Out:
# [[-1.13137085e+03 -1.13137085e+03]
#  [-1.27731159e-13 -1.27731159e-13]
#  [ 7.25530747e-14  7.25530747e-14]
#  [ 6.37268016e-14  6.37268016e-14]
#  [ 7.73825448e-14  7.73825448e-14]
#  [-1.13409282e-13 -1.13409282e-13]
#  [ 7.18869408e-14  7.18869408e-14]
#  [-1.35336187e-13 -1.35336187e-13]
#  [ 8.72080186e-14  8.72080186e-14]
#  [-3.10307335e-14 -3.10307335e-14]
#  [ 4.64628336e-14  4.64628336e-14]
#  [-2.10942375e-14 -2.10942375e-14]
#  [ 1.13964393e-13  1.13964393e-13]
#  [-7.40518757e-14 -7.40518757e-14]
#  [ 7.03881398e-14  7.03881398e-14]
#  [ 2.25708341e-13  2.25708341e-13]
#  [-9.75886039e-14 -9.75886039e-14]
#  [-1.17350574e-13 -1.17350574e-13]
#  [ 3.23630012e-14  3.23630012e-14]
#  [ 6.42819131e-14  6.42819131e-14]]

# %%
A = np.zeros((5000))
frame_length = 1024
hop_length = 80
frames = librosa.util.frame(A, frame_length=frame_length, hop_length=hop_length).astype(np.float64).T
mfcc = pysptk.sptk.mfcc(frames, order=20, fs=16000, 
                        alpha=0.97, eps=1.0, window_len=None, frame_len=None, 
                        num_filterbanks=20, cepslift=22, use_dft=False, use_hamming=False, 
                        czero=True, power=True) # shape = (n_mfcc, t)
print(mfcc)
# Out:
# [[ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]
#  [ 0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00
#    0.e+00  0.e+00  0.e+00  0.e+00  0.e+00  0.e+00 -1.e+10]]
