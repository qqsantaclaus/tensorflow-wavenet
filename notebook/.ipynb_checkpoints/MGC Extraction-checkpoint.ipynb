# %% [markdown]
# # MGC Feature Extraction
# This notebook demonstrates how to analyze speech and re-synthesis speech waveform from speech parameters using [pysptk](https://github.com/r9y9/pysptk) (and other useful speech/audio/music analysis packages). Synthesized audio examples are provided so that you are able to compare synthesis filters on your browser.
#
# ## Requirements
#
# - pysptk: https://github.com/r9y9/pysptk
# - scipy
# - librosa: https://github.com/bmcfee/librosa
# - seaborn: https://github.com/mwaskom/seaborn

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/visualai/jiaqis/tensorflow-wavenet/ENV/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['copy', 'random', 'gamma']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import matplotlib
import seaborn
seaborn.set(style="dark")
rcParams['figure.figsize'] = (16, 5)

# %%
from IPython.display import Audio
import IPython.display

# %%
import numpy as np
import sys
import librosa
import librosa.display
import pysptk
from scipy.io import wavfile

# %% [markdown]
# ## Data Load

# %%
import copy
import fnmatch
import os
import random
import re

import pandas as pd
import json

def find_files(directory, pattern='*.wav'):
    '''Recursively finds all files matching the pattern.'''
    files = []
    for root, dirnames, filenames in os.walk(directory):
        for filename in fnmatch.filter(filenames, pattern):
            files.append(os.path.join(root, filename))
    return files

# %% [markdown]
# ## Source parameter extraction
#
# ### Framing and windowing

# %%
frame_length = 1024
hop_length = 80

def windowing(x):
    # Note that almost all of pysptk functions assume input array is C-contiguous and np.float4 element type
    frames = librosa.util.frame(x, frame_length=frame_length, hop_length=hop_length).astype(np.float64).T

    # Windowing
    frames *= pysptk.blackman(frame_length)
    assert frames.shape[1] == frame_length 
    return frames

# %% [markdown]
# ### F0 estimation

# %%
# F0 estimation
def f0_estimation(x):
    f0 = pysptk.swipe(x.astype(np.float64), fs=sr, hopsize=hop_length, min=60, max=240, otype="f0")
    plot(f0, linewidth=3, label="F0 trajectory estimated by SWIPE'")
    xlim(0, len(f0))
    legend(prop={'size': 16})
    return f0

# %% [markdown]
# ## Mel-generalized cepstrum extraction

# %%
# Order of mel-cepstrum
order = 25
alpha = 0.41
stage = 5
gamma = -1.0 / stage

def mgcep(frames, sr, order=order):
    mgc = pysptk.mgcep(frames, order, alpha, gamma, min_det=0)
    # logH = pysptk.mgc2sp(mgc, alpha, gamma, frame_length).real
    # librosa.display.specshow(logH.T, sr=sr, hop_length=hop_length, x_axis="time", y_axis="linear")
    # colorbar()
    # title("Spectral envelope estimate from mel-generalized cepstrm")
    # sys.stdout.flush()
    return mgc

# %%
def generate_mgc(directory, sample_rate, lc_ext_name=".csv"):
    files = find_files(directory,  pattern="*.wav")
    for index, filename in enumerate(files):
        print(str(index)+"/"+str(len(files)))
        print(filename)
        lc_filename = copy.deepcopy(filename)
        if lc_filename.endswith('.wav'):
            lc_filename = lc_filename[:-4] + lc_ext_name
        lc_filename = lc_filename.replace("wav", "mgc")
        if os.path.isfile(lc_filename):
           IPython.display.clear_output(wait=True)
           continue
        audio, _ = librosa.load(filename, sr=sample_rate, mono=True)
        frames = windowing(audio)
        mgc = mgcep(frames, sample_rate)
        print(str(mgc.shape))
        df = pd.DataFrame(mgc)
        if not os.path.exists(os.path.dirname(lc_filename)):
            try:
                os.makedirs(os.path.dirname(lc_filename))
            except OSError as exc: # Guard against race condition
                if exc.errno != errno.EEXIST:
                    raise
        print(lc_filename)
        df.to_csv(lc_filename, sep=',', header=None, index=None) 
        IPython.display.clear_output(wait=True)

# %%
def generate_lc_map(directory):
    files = find_files(directory, pattern="*.wav")
    print("files length: {}".format(len(files)))
    lookup = {}
    for filename in files:
        p_filename = filename.split(directory)[-1]
        p_lc_filename = p_filename.replace("wav/", "mgc/").replace(".wav", ".csv")
        #p_lc_filename = "../../mgc26/"+p_filename.replace(".wav", ".csv")
        lookup[p_filename] = p_lc_filename
    with open(directory+"/mgc.json", "w") as output:
        json.dump(lookup, output)
    print lookup

# %%
generate_mgc("../../cmu_us_slt_arctic", 16000, lc_ext_name=".csv")
# Out:
# 1131/1132
# ../../cmu_us_slt_arctic/wav/arctic_a0166.wav

# %%
generate_lc_map("../../cmu_us_slt_arctic/")
# Out:
# files length: 1132
# {'wav/arctic_a0566.wav': 'mgc/arctic_a0566.mgc', 'wav/arctic_b0212.wav': 'mgc/arctic_b0212.mgc', 'wav/arctic_a0063.wav': 'mgc/arctic_a0063.mgc', 'wav/arctic_b0374.wav': 'mgc/arctic_b0374.mgc', 'wav/arctic_b0111.wav': 'mgc/arctic_b0111.mgc', 'wav/arctic_b0152.wav': 'mgc/arctic_b0152.mgc', 'wav/arctic_b0221.wav': 'mgc/arctic_b0221.mgc', 'wav/arctic_a0104.wav': 'mgc/arctic_a0104.mgc', 'wav/arctic_b0538.wav': 'mgc/arctic_b0538.mgc', 'wav/arctic_b0009.wav': 'mgc/arctic_b0009.mgc', 'wav/arctic_b0396.wav': 'mgc/arctic_b0396.mgc', 'wav/arctic_b0503.wav': 'mgc/arctic_b0503.mgc', 'wav/arctic_a0397.wav': 'mgc/arctic_a0397.mgc', 'wav/arctic_a0163.wav': 'mgc/arctic_a0163.mgc', 'wav/arctic_a0504.wav': 'mgc/arctic_a0504.mgc', 'wav/arctic_b0164.wav': 'mgc/arctic_b0164.mgc', 'wav/arctic_a0166.wav': 'mgc/arctic_a0166.mgc', 'wav/arctic_a0523.wav': 'mgc/arctic_a0523.mgc', 'wav/arctic_a0248.wav': 'mgc/arctic_a0248.mgc', 'wav/arctic_a0184.wav': 'mgc/arctic_a0184.mgc', 'wav/arctic_a0527.wav': 'mgc/arctic_a0527.mgc', 'wav/arctic_b0502.wav': 'mgc/arctic_b0502.mgc', 'wav/arctic_a0199.wav': 'mgc/arctic_a0199.mgc', 'wav/arctic_b0261.wav': 'mgc/arctic_b0261.mgc', 'wav/arctic_b0468.wav': 'mgc/arctic_b0468.mgc', 'wav/arctic_a0478.wav': 'mgc/arctic_a0478.mgc', 'wav/arctic_a0230.wav': 'mgc/arctic_a0230.mgc', 'wav/arctic_b0444.wav': 'mgc/arctic_b0444.mgc', 'wav/arctic_a0053.wav': 'mgc/arctic_a0053.mgc', 'wav/arctic_a0091.wav': 'mgc/arctic_a0091.mgc', 'wav/arctic_a0179.wav': 'mgc/arctic_a0179.mgc', 'wav/arctic_a0520.wav': 'mgc/arctic_a0520.mgc', 'wav/arctic_a0120.wav': 'mgc/arctic_a0120.mgc', 'wav/arctic_b0489.wav': 'mgc/arctic_b0489.mgc', 'wav/arctic_a0548.wav': 'mgc/arctic_a0548.mgc', 'wav/arctic_a0535.wav': 'mgc/arctic_a0535.mgc', 'wav/arctic_a0228.wav': 'mgc/arctic_a0228.mgc', 'wav/arctic_a0545.wav': 'mgc/arctic_a0545.mgc', 'wav/arctic_b0224.wav': 'mgc/arctic_b0224.mgc', 'wav/arctic_a0023.wav': 'mgc/arctic_a0023.mgc', 'wav/arctic_b0478.wav': 'mgc/arctic_b0478.mgc', 'wav/arctic_b0517.wav': 'mgc/arctic_b0517.mgc', 'wav/arctic_a0299.wav': 'mgc/arctic_a0299.mgc', 'wav/arctic_b0031.wav': 'mgc/arctic_b0031.mgc', 'wav/arctic_b0162.wav': 'mgc/arctic_b0162.mgc', 'wav/arctic_b0042.wav': 'mgc/arctic_b0042.mgc', 'wav/arctic_a0417.wav': 'mgc/arctic_a0417.mgc', 'wav/arctic_a0345.wav': 'mgc/arctic_a0345.mgc', 'wav/arctic_b0203.wav': 'mgc/arctic_b0203.mgc', 'wav/arctic_b0098.wav': 'mgc/arctic_b0098.mgc', 'wav/arctic_a0398.wav': 'mgc/arctic_a0398.mgc', 'wav/arctic_a0507.wav': 'mgc/arctic_a0507.mgc', 'wav/arctic_a0180.wav': 'mgc/arctic_a0180.mgc', 'wav/arctic_a0366.wav': 'mgc/arctic_a0366.mgc', 'wav/arctic_a0308.wav': 'mgc/arctic_a0308.mgc', 'wav/arctic_b0016.wav': 'mgc/arctic_b0016.mgc', 'wav/arctic_a0189.wav': 'mgc/arctic_a0189.mgc', 'wav/arctic_b0435.wav': 'mgc/arctic_b0435.mgc', 'wav/arctic_a0082.wav': 'mgc/arctic_a0082.mgc', 'wav/arctic_a0538.wav': 'mgc/arctic_a0538.mgc', 'wav/arctic_b0475.wav': 'mgc/arctic_b0475.mgc', 'wav/arctic_b0364.wav': 'mgc/arctic_b0364.mgc', 'wav/arctic_b0345.wav': 'mgc/arctic_b0345.mgc', 'wav/arctic_b0163.wav': 'mgc/arctic_b0163.mgc', 'wav/arctic_a0356.wav': 'mgc/arctic_a0356.mgc', 'wav/arctic_a0416.wav': 'mgc/arctic_a0416.mgc', 'wav/arctic_b0061.wav': 'mgc/arctic_b0061.mgc', 'wav/arctic_b0465.wav': 'mgc/arctic_b0465.mgc', 'wav/arctic_a0250.wav': 'mgc/arctic_a0250.mgc', 'wav/arctic_a0424.wav': 'mgc/arctic_a0424.mgc', 'wav/arctic_a0337.wav': 'mgc/arctic_a0337.mgc', 'wav/arctic_a0484.wav': 'mgc/arctic_a0484.mgc', 'wav/arctic_b0416.wav': 'mgc/arctic_b0416.mgc', 'wav/arctic_b0192.wav': 'mgc/arctic_b0192.mgc', 'wav/arctic_a0373.wav': 'mgc/arctic_a0373.mgc', 'wav/arctic_a0554.wav': 'mgc/arctic_a0554.mgc', 'wav/arctic_a0539.wav': 'mgc/arctic_a0539.mgc', 'wav/arctic_b0234.wav': 'mgc/arctic_b0234.mgc', 'wav/arctic_b0096.wav': 'mgc/arctic_b0096.mgc', 'wav/arctic_a0350.wav': 'mgc/arctic_a0350.mgc', 'wav/arctic_a0354.wav': 'mgc/arctic_a0354.mgc', 'wav/arctic_b0404.wav': 'mgc/arctic_b0404.mgc', 'wav/arctic_b0070.wav': 'mgc/arctic_b0070.mgc', 'wav/arctic_a01 ...
