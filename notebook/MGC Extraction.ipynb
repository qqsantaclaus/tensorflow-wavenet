# %% [markdown]
# # MGC Feature Extraction
# This notebook demonstrates how to analyze speech and re-synthesis speech waveform from speech parameters using [pysptk](https://github.com/r9y9/pysptk) (and other useful speech/audio/music analysis packages). Synthesized audio examples are provided so that you are able to compare synthesis filters on your browser.
#
# ## Requirements
#
# - pysptk: https://github.com/r9y9/pysptk
# - scipy
# - librosa: https://github.com/bmcfee/librosa
# - seaborn: https://github.com/mwaskom/seaborn

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib
import seaborn
seaborn.set(style="dark")
rcParams['figure.figsize'] = (16, 5)

# %%
from IPython.display import Audio
import IPython.display

# %%
import numpy as np
import sys
import librosa
import librosa.display
import pysptk
from scipy.io import wavfile

# %% [markdown]
# ## Data Load

# %%
import copy
import fnmatch
import os
import random
import re

import pandas as pd
import json

def find_files(directory, pattern='*.wav'):
    '''Recursively finds all files matching the pattern.'''
    files = []
    for root, dirnames, filenames in os.walk(directory):
        for filename in fnmatch.filter(filenames, pattern):
            files.append(os.path.join(root, filename))
    return files

# %% [markdown]
# ## Source parameter extraction
#
# ### Framing and windowing

# %%
frame_length = 1024
hop_length = 80

def windowing(x):
    # Note that almost all of pysptk functions assume input array is C-contiguous and np.float4 element type
    frames = librosa.util.frame(x, frame_length=frame_length, hop_length=hop_length).astype(np.float64).T

    # Windowing
    frames *= pysptk.blackman(frame_length)
    assert frames.shape[1] == frame_length 
    return frames

# %% [markdown]
# ### F0 estimation

# %%
# F0 estimation
def f0_estimation(x):
    f0 = pysptk.swipe(x.astype(np.float64), fs=sr, hopsize=hop_length, min=60, max=240, otype="f0")
    plot(f0, linewidth=3, label="F0 trajectory estimated by SWIPE'")
    xlim(0, len(f0))
    legend(prop={'size': 16})
    return f0

# %% [markdown]
# ## Mel-generalized cepstrum extraction

# %%
# Order of mel-cepstrum
order = 25
alpha = 0.41
stage = 5
gamma = -1.0 / stage

def mgcep(frames, sr, order=order):
    mgc = pysptk.mgcep(frames, order, alpha, gamma, min_det=0)
    # logH = pysptk.mgc2sp(mgc, alpha, gamma, frame_length).real
    # librosa.display.specshow(logH.T, sr=sr, hop_length=hop_length, x_axis="time", y_axis="linear")
    # colorbar()
    # title("Spectral envelope estimate from mel-generalized cepstrm")
    # sys.stdout.flush()
    return mgc

# %%
def generate_mgc(directory, sample_rate, lc_ext_name=".csv"):
    files = find_files(directory,  pattern="p225*.wav")
    for index, filename in enumerate(files):
        print(str(index)+"/"+str(len(files)))
        print(filename)
        lc_filename = copy.deepcopy(filename)
        if lc_filename.endswith('.wav'):
            lc_filename = lc_filename[:-4] + lc_ext_name
        lc_filename = lc_filename.replace("wav48", "mgc")
        if os.path.isfile(lc_filename):
            IPython.display.clear_output(wait=True)
            continue
        audio, _ = librosa.load(filename, sr=sample_rate, mono=True)
        frames = windowing(audio)
        mgc = mgcep(frames, sample_rate)
        print(str(mgc.shape))
        df = pd.DataFrame(mgc)
        if not os.path.exists(os.path.dirname(lc_filename)):
            try:
                os.makedirs(os.path.dirname(lc_filename))
            except OSError as exc: # Guard against race condition
                if exc.errno != errno.EEXIST:
                    raise
        print(lc_filename)
        df.to_csv(lc_filename, sep=',', header=None, index=None) 
        IPython.display.clear_output(wait=True)

# %%
def generate_lc_map(directory):
    files = find_files(directory, pattern="p225*.wav")
    print("files length: {}".format(len(files)))
    lookup = {}
    for filename in files:
        p_filename = filename.split(directory)[-1]
        # p_lc_filename = p_filename.replace("wav48", "mfcc").replace(".wav", ".csv")
        p_lc_filename = "../../mgc/p225"+p_filename.replace(".wav", ".csv")
        lookup[p_filename] = p_lc_filename
    with open(directory+"/mgc_p225.json", "w") as output:
        json.dump(lookup, output)
    print lookup

# %%
generate_mgc("../../VCTK-Corpus", 16000, lc_ext_name=".csv")
# Out:
# 230/231
# ../../VCTK-Corpus/wav48/p225/p225_145.wav

# %%
generate_lc_map("../../VCTK-Corpus/wav48/p225")
# Out:
# files length: 231
# ../../VCTK-Corpus/wav48/p225/p225_208.wav /p225_208.wav
# ../../VCTK-Corpus/wav48/p225/p225_061.wav /p225_061.wav
# ../../VCTK-Corpus/wav48/p225/p225_060.wav /p225_060.wav
# ../../VCTK-Corpus/wav48/p225/p225_066.wav /p225_066.wav
# ../../VCTK-Corpus/wav48/p225/p225_159.wav /p225_159.wav
# ../../VCTK-Corpus/wav48/p225/p225_147.wav /p225_147.wav
# ../../VCTK-Corpus/wav48/p225/p225_090.wav /p225_090.wav
# ../../VCTK-Corpus/wav48/p225/p225_008.wav /p225_008.wav
# ../../VCTK-Corpus/wav48/p225/p225_051.wav /p225_051.wav
# ../../VCTK-Corpus/wav48/p225/p225_244.wav /p225_244.wav
# ../../VCTK-Corpus/wav48/p225/p225_329.wav /p225_329.wav
# ../../VCTK-Corpus/wav48/p225/p225_174.wav /p225_174.wav
# ../../VCTK-Corpus/wav48/p225/p225_104.wav /p225_104.wav
# ../../VCTK-Corpus/wav48/p225/p225_354.wav /p225_354.wav
# ../../VCTK-Corpus/wav48/p225/p225_083.wav /p225_083.wav
# ../../VCTK-Corpus/wav48/p225/p225_319.wav /p225_319.wav
# ../../VCTK-Corpus/wav48/p225/p225_021.wav /p225_021.wav
# ../../VCTK-Corpus/wav48/p225/p225_257.wav /p225_257.wav
# ../../VCTK-Corpus/wav48/p225/p225_274.wav /p225_274.wav
# ../../VCTK-Corpus/wav48/p225/p225_033.wav /p225_033.wav
# ../../VCTK-Corpus/wav48/p225/p225_057.wav /p225_057.wav
# ../../VCTK-Corpus/wav48/p225/p225_277.wav /p225_277.wav
# ../../VCTK-Corpus/wav48/p225/p225_001.wav /p225_001.wav
# ../../VCTK-Corpus/wav48/p225/p225_172.wav /p225_172.wav
# ../../VCTK-Corpus/wav48/p225/p225_038.wav /p225_038.wav
# ../../VCTK-Corpus/wav48/p225/p225_114.wav /p225_114.wav
# ../../VCTK-Corpus/wav48/p225/p225_142.wav /p225_142.wav
# ../../VCTK-Corpus/wav48/p225/p225_065.wav /p225_065.wav
# ../../VCTK-Corpus/wav48/p225/p225_220.wav /p225_220.wav
# ../../VCTK-Corpus/wav48/p225/p225_347.wav /p225_347.wav
# ../../VCTK-Corpus/wav48/p225/p225_094.wav /p225_094.wav
# ../../VCTK-Corpus/wav48/p225/p225_197.wav /p225_197.wav
# ../../VCTK-Corpus/wav48/p225/p225_353.wav /p225_353.wav
# ../../VCTK-Corpus/wav48/p225/p225_295.wav /p225_295.wav
# ../../VCTK-Corpus/wav48/p225/p225_239.wav /p225_239.wav
# ../../VCTK-Corpus/wav48/p225/p225_135.wav /p225_135.wav
# ../../VCTK-Corpus/wav48/p225/p225_177.wav /p225_177.wav
# ../../VCTK-Corpus/wav48/p225/p225_280.wav /p225_280.wav
# ../../VCTK-Corpus/wav48/p225/p225_241.wav /p225_241.wav
# ../../VCTK-Corpus/wav48/p225/p225_175.wav /p225_175.wav
# ../../VCTK-Corpus/wav48/p225/p225_013.wav /p225_013.wav
# ../../VCTK-Corpus/wav48/p225/p225_316.wav /p225_316.wav
# ../../VCTK-Corpus/wav48/p225/p225_026.wav /p225_026.wav
# ../../VCTK-Corpus/wav48/p225/p225_117.wav /p225_117.wav
# ../../VCTK-Corpus/wav48/p225/p225_023.wav /p225_023.wav
# ../../VCTK-Corpus/wav48/p225/p225_350.wav /p225_350.wav
# ../../VCTK-Corpus/wav48/p225/p225_302.wav /p225_302.wav
# ../../VCTK-Corpus/wav48/p225/p225_349.wav /p225_349.wav
# ../../VCTK-Corpus/wav48/p225/p225_016.wav /p225_016.wav
# ../../VCTK-Corpus/wav48/p225/p225_028.wav /p225_028.wav
# ../../VCTK-Corpus/wav48/p225/p225_046.wav /p225_046.wav
# ../../VCTK-Corpus/wav48/p225/p225_279.wav /p225_279.wav
# ../../VCTK-Corpus/wav48/p225/p225_012.wav /p225_012.wav
# ../../VCTK-Corpus/wav48/p225/p225_294.wav /p225_294.wav
# ../../VCTK-Corpus/wav48/p225/p225_037.wav /p225_037.wav
# ../../VCTK-Corpus/wav48/p225/p225_289.wav /p225_289.wav
# ../../VCTK-Corpus/wav48/p225/p225_025.wav /p225_025.wav
# ../../VCTK-Corpus/wav48/p225/p225_145.wav /p225_145.wav
# {'/p225_323.wav': '../../mgc/p225/p225_323.csv', '/p225_084.wav': '../../mgc/p225/p225_084.csv', '/p225_287.wav': '../../mgc/p225/p225_287.csv', '/p225_024.wav': '../../mgc/p225/p225_024.csv', '/p225_012.wav': '../../mgc/p225/p225_012.csv', '/p225_244.wav': '../../mgc/p225/p225_244.csv', '/p225_018.wav': '../../mgc/p225/p225_018.csv', '/p225_290.wav': '../../mgc/p225/p225_290.csv', '/p225_300.wav': '../../mgc/p225/p225_300.csv', '/p225_366.wav': '../../mgc/p225/p225_366.csv', '/p225_116.wav': '../../mgc/p225/p225_116.csv', '/p225_037.wav': '../../mgc/p225/p225_037.csv', '/p225_151.wav': '../../mgc/p225/p225_151.csv', '/p225_040.wav': '../../mgc/p225/p225_040.csv', '/p225_224.wav': '../../mgc/p225/p225_224.csv', '/p225_020.wav': '../../mgc/p225/p225_020.csv', '/p225_280.wav': '../../mgc/p225/p225_280.csv', '/p225_322.wav': '../../mgc/p225/p225_322.csv', '/p225_325.wav': '../../mgc/p225/p225_325.csv', '/p225_254.wav': '../../mgc/p225/p225_254.csv', '/p225_066.wav': '../../mgc/p225/p225_066.csv', '/p225_144.wav': '../../mgc/p225/p225_144.csv', '/p225_030.wav': '../../mgc/p225/p225_030.csv', '/p225_171.wav': '../../mgc/p225/p225_171.csv', '/p225_210.wav': '../../mgc/p225/p225_210.csv', '/p225_265.wav': '../../mgc/p225/p225_265.csv', '/p225_350.wav': '../../mgc/p225/p225_350.csv', '/p225_064.wav': '../../mgc/p225/p225_064.csv', '/p225_268.wav': '../../mgc/p225/p225_268.csv', '/p225_298.wav': '../../mgc/p225/p225_298.csv', '/p225_060.wav': '../../mgc/p225/p225_060.csv', '/p225_335.wav': '../../mgc/p225/p225_335.csv', '/p225_114.wav': '../../mgc/p225/p225_114.csv', '/p225_021.wav': '../../mgc/p225/p225_021.csv', '/p225_329.wav': '../../mgc/p225/p225_329.csv', '/p225_111.wav': '../../mgc/p225/p225_111.csv', '/p225_296.wav': '../../mgc/p225/p225_296.csv', '/p225_141.wav': '../../mgc/p225/p225_141.csv', '/p225_199.wav': '../../mgc/p225/p225_199.csv', '/p225_363.wav': '../../mgc/p225/p225_363.csv', '/p225_157.wav': '../../mgc/p225/p225_157.csv', '/p225_317.wav': '../../mgc/p225/p225_317.csv', '/p225_008.wav': '../../mgc/p225/p225_008.csv', '/p225_223.wav': '../../mgc/p225/p225_223.csv', '/p225_104.wav': '../../mgc/p225/p225_104.csv', '/p225_293.wav': '../../mgc/p225/p225_293.csv', '/p225_133.wav': '../../mgc/p225/p225_133.csv', '/p225_071.wav': '../../mgc/p225/p225_071.csv', '/p225_289.wav': '../../mgc/p225/p225_289.csv', '/p225_052.wav': '../../mgc/p225/p225_052.csv', '/p225_007.wav': '../../mgc/p225/p225_007.csv', '/p225_318.wav': '../../mgc/p225/p225_318.csv', '/p225_128.wav': '../../mgc/p225/p225_128.csv', '/p225_136.wav': '../../mgc/p225/p225_136.csv', '/p225_115.wav': '../../mgc/p225/p225_115.csv', '/p225_109.wav': '../../mgc/p225/p225_109.csv', '/p225_051.wav': '../../mgc/p225/p225_051.csv', '/p225_276.wav': '../../mgc/p225/p225_276.csv', '/p225_200.wav': '../../mgc/p225/p225_200.csv', '/p225_062.wav': '../../mgc/p225/p225_062.csv', '/p225_061.wav': '../../mgc/p225/p225_061.csv', '/p225_103.wav': '../../mgc/p225/p225_103.csv', '/p225_326.wav': '../../mgc/p225/p225_326.csv', '/p225_192.wav': '../../mgc/p225/p225_192.csv', '/p225_094.wav': '../../mgc/p225/p225_094.csv', '/p225_193.wav': '../../mgc/p225/p225_193.csv', '/p225_331.wav': '../../mgc/p225/p225_331.csv', '/p225_174.wav': '../../mgc/p225/p225_174.csv', '/p225_211.wav': '../../mgc/p225/p225_211.csv', '/p225_294.wav': '../../mgc/p225/p225_294.csv', '/p225_046.wav': '../../mgc/p225/p225_046.csv', '/p225_057.wav': '../../mgc/p225/p225_057.csv', '/p225_092.wav': '../../mgc/p225/p225_092.csv', '/p225_003.wav': '../../mgc/p225/p225_003.csv', '/p225_152.wav': '../../mgc/p225/p225_152.csv', '/p225_017.wav': '../../mgc/p225/p225_017.csv', '/p225_240.wav': '../../mgc/p225/p225_240.csv', '/p225_009.wav': '../../mgc/p225/p225_009.csv', '/p225_175.wav': '../../mgc/p225/p225_175.csv', '/p225_014.wav': '../../mgc/p225/p225_014.csv', '/p225_013.wav': '../../mgc/p225/p225_013.csv', '/p225_126.wav': '../../mgc/p225/p225_126.csv', '/p225_145.wav': '../../mgc/p225/p225_145.csv', '/p225_273.wav' ...
